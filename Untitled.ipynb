# %%
import pandas as pd
import re
import string
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score

# %%
df=pd.read_csv("C:/Users/maths/Desktop/FML-AVI-230957164/Womens Clothing E-Commerce Reviews.csv")
df.head()
# Out:
#    Unnamed: 0  Clothing ID  Age                    Title  \
# 0           0          767   33                      NaN
# 1           1         1080   34                      NaN
# 2           2         1077   60  Some major design flaws
# 3           3         1049   50         My favorite buy!
# 4           4          847   47         Flattering shirt
#
#                                          Review Text  Rating  Recommended IND  \
# 0  Absolutely wonderful - silky and sexy and comf...       4                1
# 1  Love this dress!  it's sooo pretty.  i happene...       5                1
# 2  I had such high hopes for this dress and reall...       3                0
# 3  I love, love, love this jumpsuit. it's fun, fl...       5                1
# 4  This shirt is very flattering to all due to th...       5                1
#
#    Positive Feedback Count   Division Name Department Name Class Name
# 0                        0       Initmates        Intimate  Intimates
# 1                        4         General         Dresses    Dresses
# 2                        0         General         Dresses    Dresses
# 3                        0  General Petite         Bottoms      Pants
# 4                        6         General            Tops    Blouses

# %%
print(df.isnull().sum())
df=df.dropna()
# Out:
# Unnamed: 0                    0
# Clothing ID                   0
# Age                           0
# Title                      3810
# Review Text                 845
# Rating                        0
# Recommended IND               0
# Positive Feedback Count       0
# Division Name                14
# Department Name              14
# Class Name                   14
# dtype: int64

# %%
review_count=df['Clothing ID'].value_counts()
df_filtered=df[df['Clothing ID'].isin(review_count[review_count>5].index)]
df=df_filtered.sort_values(by='Clothing ID',ascending=True)
df.head(20)
# Out:
#        Unnamed: 0  Clothing ID  Age                                  Title  \
# 16698       16698            8   38           Cute suit-didn't work for me
# 16695       16695            8   33                         Great coverage
# 16731       16731            8   33                        Love this suit!
# 16711       16711            8   70           Alas not as good as it looks
# 16737       16737            8   36                    Not what i expected
# 16703       16703            8   57                            Retro style
# 16739       16739            8   42              Such a nice bathing suit!
# 18528       18528           24   37                    Love this swimsuit!
# 18523       18523           24   39                              Worth it!
# 18535       18535           24   29                     Super unflattering
# 18537       18537           24   37                 Great for bigger busts
# 18543       18543           24   49                         Great coverage
# 18518       18518           24   27  Fun and gorgeous suit, but not for me
# 11107       11107           90   36                              Love them
# 11084       11084           90   62                   The perfect leggings
# 11085       11085           90   39                  Better than leggings!
# 11110       11110           90   51                     Best leggings ever
# 11091       11091           90   30                        Great leggings!
# 11100       11100           90   52                             Good basic
# 11109       11109           90   43                Too much like jodphurs!
#
#                                              Review Text  Rating  \
# 16698  This suit was high quality, and a cute design....       1
# 16695  This bathing suit has everything. i especially...       5
# 16731  I am 5'5, 150lb, generally size medium shirt, ...       5
# 16711  The suit is lovely, but it is very long in the...       2
# 16737  I bought this suit based on the great reviews....       2
# 16703  I bought a size 8 a few years back not my regu...       5
# 16739  This is my first one piece bathing suit, and i...       5
# 18528  This swimsuit is super cute and retro. the ruc...       5
# 18523  This suit is great for curvy and slightly flaw...       5
# 18535  I'm 5' 5", 150 lbs, 32dd, normally a 28p or 29...       2
# 18537  I absolutely love the retro look of this swims...       5
# 18543  I ordered the correct size due to reading othe...       5
# 18518  This was the first suit i've ever ordered onli...       4
# 11107  They are a perfect thickness. fits comfortably...       5
# 11084  I've been looking for the right leggings that ...       5
# 11085  I'd describe these as a hybrid pant/legging. t...       5
# 11110  After reading the reviews, these leggings seem...       4
# 11091  Wonderful fit - love that these have a bit of ...       4
# 11100  Great pair of black pants, a step up from basi...       5
# 11109  Good quality fabric and structure but the mix ...       2
#
#        Recommended IND  Positive Feedback Count Division Name Department Name  \
# 16698                0                        0     Initmates        Intimate
# 16695                1                        2     Initmates        Intimate
# 16731                1                        0     Initmates        Intimate
# 16711                0                        0     Initmates        Intimate
# 16737                0                        0     Initmates        Intimate
# 16703                1                        0     Initmates        Intimate
# 16739                1                        0     Initmates        Intimate
# 18528                1                        0     Initmates        Intimate
# 18523                1                        0     Initmates        Intimate
# 18535                0                        0     Initmates        Intimate
# 18537                1                        0     Initmates        Intimate
# 18543                1                        0     Initmates        Intimate
# 18518                1                        0     Initmates        Intimate
# 11107                1                        1     Initmates        Intimate
# 11084                1                        0     Initmates        Intimate
# 11085                1                        0     Initmates        Intimate
# 11110                1                        0     Initmates        Intimate
# 11091                1                        1     Initmates        Intimate
# 11100                1                        1     Initmates        Intimate
# 11109                0                        0     Initmates        Intimate
#
#       Class Name
# 16698       Swim
# 16695       Swim
# 16731       Swim
# 16711       Swim
# 16737       Swim
# 16703       Swim
# 16739       Swim
# 18528       Swim
# 18523       Swim
# 18535       Swim
# 18537       Swim
# 18543       Swim
# 18518       Swim
# 11107    Legwear
# 11084    Legwear
# 11085    Legwear
# 11110    Legwear
# 11091    Legwear
# 11100    Legwear
# 11109    Legwear

# %%
contractions_dict = {
    "don't": "do not", "won't": "will not", "can't": "cannot", "i'm": "i am", 
    "it's": "it is", "that's": "that is", "he's": "he is", "she's": "she is", 
    "we're": "we are", "they're": "they are", "you're": "you are", 
    "didn't": "did not", "doesn't": "does not", "wasn't": "was not", "weren't": "were not",
    "hasn't": "has not", "haven't": "have not", "i've": "i have", "we've": "we have",
    "you've": "you have", "they've": "they have", "i'll": "i will", "you'll": "you will",
    "he'll": "he will", "she'll": "she will", "we'll": "we will", "they'll": "they will",
    "i'd": "i would", "you'd": "you would", "he'd": "he would", "she'd": "she would",
    "we'd": "we would", "they'd": "they would"
}
def expand_contractions(text):
    for contraction, expansion in contractions_dict.items():
        text = text.replace(contraction, expansion)
    return text
def clean_text(text):
    text = text.lower()  # Convert to lowercase
    text = expand_contractions(text)  # Expand contractions
    text = re.sub(r'[^\w\s]', '', text)  # Remove punctuation
    return text
df['Review Text'] = df['Review Text'].apply(clean_text)
df['Title'] = df['Title'].apply(clean_text)
df.head(20)
