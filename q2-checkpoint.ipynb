# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, accuracy_score, roc_curve, auc
import seaborn as sns

# %%
df=pd.read_csv('diabetes.csv')
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome  Unnamed: 9  Unnamed: 10  \
# 0                     0.627   50        1         NaN          NaN
# 1                     0.351   31        0         NaN          NaN
# 2                     0.672   32        1         NaN          NaN
# 3                     0.167   21        0         NaN          NaN
# 4                     2.288   33        1         NaN          NaN
#
#                                          Unnamed: 11
# 0                                                NaN
# ...

# %%
mean_Age=df['Age'].mean()
Std_Age=df['Age'].std()
print("mean fo age:                ",mean_Age)
print("standard deviation of age:  ",Std_Age)
# Out:
# mean fo age:                 33.240885416666664
# standard deviation of age:   11.76023154067868

# %%
plt.figure(figsize=(8, 6))
sns.histplot(df['Age'],bins=20)
plt.title('Age Distribution of Patients')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
classes = df.groupby('Outcome')[['Age', 'BMI']].describe()
classes
# Out:
#            Age                                                        BMI  \
#          count       mean        std   min   25%   50%   75%   max  count
# Outcome
# 0        500.0  31.190000  11.667655  21.0  23.0  27.0  37.0  81.0  500.0
# 1        268.0  37.067164  10.968254  21.0  28.0  36.0  44.0  70.0  268.0
#
#
#               mean       std  min   25%    50%     75%   max
# Outcome
# 0        30.304200  7.689855  0.0  25.4  30.05  35.300  57.3
# 1        35.142537  7.262967  0.0  30.8  34.25  38.775  67.1

# %%
class_distribution = df['Outcome'].value_counts()

sns.countplot(x='Outcome', data=df)
plt.title('Class Distribution')
plt.xlabel('Class Label (0: Non-Diabetic, 1: Diabetic)')
plt.ylabel('Count')
plt.show()

class_distribution
# Out:
# 0    500
# 1    268
# Name: Outcome, dtype: int64

# %%
# x=df[['Pregnancies','Glucose','BloodPressure','SkinThickness','Insulin','BMI','DiabetesPedigreeFunction','Age']]
# y=df['Outcome']

# x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# model = LogisticRegression(max_iter=1000)

# model.fit(x_train, y_train)

# y_pred = model.predict(x_test)
# Step 1: Import libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, accuracy_score, roc_curve, auc
from sklearn.preprocessing import StandardScaler

# Step 2: Load your dataset (assuming dataset is in CSV format)
# Replace 'your_dataset.csv' with the actual file name or data loading cod

# Assume your dataset has features in columns and the target variable is 'target'
# Split the data into features (X) and target (y)
X = df[['Pregnancies','Glucose','BloodPressure','SkinThickness','Insulin','BMI','DiabetesPedigreeFunction','Age']] # Replace 'target' with actual target column name
y = df['Outcome'] # Replace 'target' with actual target column name

# Step 3: Split the dataset into training and test sets (70% train, 30% test)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Step 4: Standardize the features (optional but recommended for logistic regression)
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Step 5: Train the Logistic Regression model
model = LogisticRegression()
model.fit(X_train, y_train)

# Step 6: Predict on the test set
y_pred = model.predict(X_test)

# Step 7: Compute the confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Step 8: Visualize the confusion matrix using a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=["Negative", "Positive"], yticklabels=["Negative", "Positive"])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# Step 9: 
accuracy = accuracy_score(y_test, y_pred)
TP = cm[1, 1]
TN = cm[0, 0]
FP = cm[0, 1]
FN = cm[1, 0]

TPR = TP / (TP + FN)  # True Positive Rate (Sensitivity)
TNR = TN / (TN + FP)  # True Negative Rate (Specificity)

print(f'Accuracy: {accuracy:.4f}')
print(f'True Positive Rate: {TPR:.4f}')
print(f'True Negative Rate: {TNR:.4f}')

# Step 10: Visualize the ROC curve
fpr, tpr, thresholds = roc_curve(y_test, model.predict_proba(X_test)[:, 1])
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()

# Step 11: Comment on the performance
print(f'Area Under the ROC Curve (AUC): {roc_auc:.4f}')
# Out:
# Accuracy: 0.7359
# True Positive Rate: 0.6250
# True Negative Rate: 0.7947
# Area Under the ROC Curve (AUC): 0.7978
